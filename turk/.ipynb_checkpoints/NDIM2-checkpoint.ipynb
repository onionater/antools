# %%
pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys 
sys.path.append('/Users/amyskerry/Dropbox/antools/utilities')
import aesbasicfunctions as abf
import analyzeNDIM as ndim
import NDIM_analysiswrappers as ndaw
import analyzeNDE as nde_data

# %%
##set whether you are analyzing pilot study or real, and specify files accordingly (setfiles has hardcoded features)
version='ver2'#or 'pilot'
rootdir, nderesultsfile, ndimresultsfile, stimfile, appraisalfile, savepath=ndim.setfiles(version)

# %%
## set values for nde and ndim (setndevals and setndimvals has hardcoded but potentally relevant features)
ndecheckquestions, ndeexpectedanswers, ndeinclusioncols, orderedemos=ndim.setndevals(version)
suffix='allvars' #to restrict analysis use 'vonly' or 'nv'
orderedemos, appraisalnames, appraisaldata, stims, item2emomapping, alldims, defaultdimordering, explicit, othercols,valenceddims, columndict, suffixmappings, excludecols=ndim.setndimvals(version, suffix, appraisalfile, stimfile)

# %%
## run nde analyses and create figs
nde_data.main(nderesultsfile, ndecheckquestions,ndeexpectedanswers,ndeinclusioncols,orderedemos)
print nderesultsfile
# Out:
# ['Grateful', 'Joyful', 'Hopeful', 'Excited', 'Proud', 'Impressed', 'Content', 'Nostalgic', 'Surprised', 'Lonely', 'Furious', 'Terrified', 'Apprehensive', 'Annoyed', 'Guilty', 'Disgusted', 'Embarrassed', 'Devastated', 'Disappointed', 'Jealous']
# /Users/amyskerry/documents/projects/turk/NDE_dim2/data/NDE_data/sqldata/NDEdl_combined.csv

# %%
#specify an intuitive ordering for dimensions (relevant when visualizing)
mydimordering=[] #fill this in with own ordering if desired
if mydimordering:
    newdimordering= ndim.reorderdims(mydimordering, excludecols, othercols, alldims) #will limit to dims in mydimordering
else: 
    newdimordering=defaultdimordering

# %%
##find useable subejcts and define vectors of labels for all items and all emotions
[subjects, entries, dimlabels]=ndim.extractndimdata(ndimresultsfile, excludecols, othercols, columndict, item2emomapping, newdimordering)
keepers=[entry for entry in entries if entry.passedcheck] #previous exclusions were unusable data collection. this is limiting to those who pass the quality check
keeperlabels=[keep.label for keep in keepers]
keeperemos=[keep.emo for keep in keepers]
qlabels=set(keeperlabels)
emolabels=set(keeperemos)
orderedlabels, orderedemos=ndim.orderlists(list(emolabels),list(qlabels),keepers,orderedemos,item2emomapping) #molabels are randomly orded, here use manually sorted labels:
keepers, numstimsperemo=ndim.assignCVfolds(keepers,item2emomapping) #add cv relevant indices to keeper entries
# Out:
# ******checking sanity of responses, making entries for the sane ones******
# Ndim21a_q012_02_294: too many items:
# Counter({'NULL': 25, 'q13': 14})
# Ndim21a_q012_02_294: too many emotions:
# Counter({'NULL': 25, 'Apprehensive': 14})
# Ndim21a_q012_02_294: contains null responses
# Ndim21a_q015_01_546: too many items:
# Counter({'NULL': 26, 'q183': 13})
# Ndim21a_q015_01_546: too many emotions:
# Counter({'NULL': 26, 'Nostalgic': 12, 'Excited': 1})
# Ndim21a_q015_01_546: contains null responses
# Ndim21a_q012_02_294: too many items:
# Counter({'q127': 29, 'NULL': 10})
# Ndim21a_q012_02_294: too many emotions:
# Counter({'Content': 28, 'NULL': 10, 'Apprehensive': 1})
# Ndim21a_q012_02_294: contains null responses
# Ndim21a_q027_01_861: too many items:
# Counter({'q28': 28, 'NULL': 11})
# Ndim21a_q027_01_861: too many emotions:
# Counter({'Devastated': 28, 'NULL': 11})
# Ndim21a_q027_01_861: contains null responses
# Ndim21a_q030_02_255: too many items:
# Counter({'NULL': 23, 'q31': 16})
# Ndim21a_q030_02_255: too many emotions:
# Counter({'NULL': 23, 'Disappointed': 16})
# Ndim21a_q030_02_255: contains null responses
# ******checking mappings******
# mistmatch for q182
# expected: Nostalgic
# observed: Guilty
# mistmatch for q109
# expected: Terrified
# observed: Impressed
# mistmatch for q196
# expected: Proud
# observed: Grateful
# mistmatch for q178
# expected: Joyful
# observed: Annoyed
# mistmatch for q147
# expected: Grateful
# observed: Lonely
# mistmatch for q158
# expected: Hopeful
# observed: Impressed

# %%
#compute item, emo, and dim avgs:
itemavgs,itemlabels,itememos,emoavgs,dimavgs=ndaw.basicdescriptives(keepers,orderedlabels, orderedemos, dimlabels, suffix, savepath)
# Out:
# found 197

# %%
#can limit to a subset of emos
#basicsubset=['Afraid', 'Joyful', 'Disgusted', 'Sad', 'Surprise', 'Angry']
#[itemavgs, itemlabels, itememos, emoavgs, emolabels]=reduce2subset(basicsubset,itemavgs, itemlabels, itememos, emoavgs, emolabels)

# %%
#do clustering analysis with number of emotions imposed:
print "****** clustering analysis******"
clusterresults=ndaw.kmeansclustering(itemavgs, itememos, emolabels)
# Out:
# ****** clustering analysis******
# 1: Content
# 1: Content
# 1: Content
# 1: Content
# 1: Content
# 1: Excited
# 1: Excited
# 1: Joyful
# 1: Joyful
# 1: Nostalgic
# 1: Nostalgic
# 1: Proud
# 1: Proud
# 1: Proud
# 1: Proud
# 1: Proud
# 1: Proud
# 2: Annoyed
# 2: Apprehensive
# 2: Apprehensive
# 2: Apprehensive
# 2: Devastated
# 2: Disappointed
# 2: Disappointed
# 2: Disappointed
# 2: Embarrassed
# 2: Furious
# 2: Impressed
# 2: Jealous
# 2: Jealous
# 2: Jealous
# 2: Jealous
# 2: Jealous
# 2: Jealous
# 2: Jealous
# 2: Lonely
# 2: Lonely
# 2: Lonely
# 2: Lonely
# 2: Lonely
# 2: Lonely
# 2: Lonely
# 2: Nostalgic
# 3: Grateful
# 3: Impressed
# 3: Impressed
# 3: Impressed
# 3: Impressed
# 3: Impressed
# 3: Joyful
# 3: Proud
# 3: Surprised
# 3: Surprised
# 3: Surprised
# 4: Grateful
# 4: Guilty
# 5: Apprehensive
# 5: Disgusted
# 5: Embarrassed
# 5: Terrified
# 5: Terrified
# 6: Apprehensive
# 6: Excited
# 6: Excited
# 6: Excited
# 6: Grateful
# 6: Grateful
# 6: Grateful
# 6: Grateful
# 6: Guilty
# 6: Hopeful
# 6: Hopeful
# 6: Hopeful
# 6: Hopeful
# 6: Hopeful
# 6: Hopeful
# 6: Hopeful
# 6: Impressed
# 6: Impressed
# 6: Impressed
# 6: Joyful
# 6: Joyful
# 6: Joyful
# 6: Joyful
# 6: Joyful
# 6: Joyful
# 6: Proud
# 6: Proud
# 6: Surprised
# 6: Surprised
# 7: Annoyed
# 7: Annoyed
# 7: Annoyed
# 7: Annoyed
# 7: Disappointed
# 7: Disgusted
# 7: Disgusted
# 7: Disgusted
# 7: Disgusted
# 7: Disgusted
# 7: Furious
# 7: Furious
# 8: Devastated
# 8: Devastated
# 8: Devastated
# 8: Devastated
# 8: Terrified
# 9: Content
# 9: Content
# 10: Content
# 10: Content
# 10: Content
# 10: Excited
# 10: Excited
# 10: Excited
# 10: Excited
# 10: Guilty
# 10: Hopeful
# 10: Lonely
# 10: Nostalgic
# 10: Nostalgic
# 10: Nostalgic
# 10: Proud
# 11: Excited
# 11: Hopeful
# 11: Lonely
# 11: Nostalgic
# 11: Nostalgic
# 11: Nostalgic
# 11: Nostalgic
# 11: Surprised
# 12: Apprehensive
# 12: Devastated
# 12: Grateful
# 12: Grateful
# 12: Hopeful
# 12: Terrified
# 13: Embarrassed
# 13: Embarrassed
# 13: Embarrassed
# 13: Guilty
# 13: Guilty
# 13: Guilty
# 14: Terrified
# 14: Terrified
# 15: Apprehensive
# 15: Disgusted
# 15: Grateful
# 15: Terrified
# 15: Terrified
# 16: Joyful
# 17: Apprehensive
# 17: Guilty
# 17: Guilty
# 17: Guilty
# 17: Guilty
# 18: Annoyed
# 18: Annoyed
# 18: Annoyed
# 18: Apprehensive
# 18: Apprehensive
# 18: Devastated
# 18: Devastated
# 18: Devastated
# 18: Disappointed
# 18: Disappointed
# 18: Disappointed
# 18: Disappointed
# 18: Embarrassed
# 18: Embarrassed
# 18: Embarrassed
# 18: Embarrassed
# 18: Furious
# 18: Furious
# 18: Jealous
# 18: Jealous
# 18: Lonely
# 18: Terrified
# 19: Annoyed
# 19: Annoyed
# 19: Devastated
# 19: Disgusted
# 19: Furious
# 19: Furious
# 19: Furious
# 19: Furious
# 19: Furious
# 20: Disappointed
# 20: Disappointed
# 20: Disgusted
# 20: Disgusted
# 20: Embarrassed
# 20: Impressed
# 20: Surprised
# 20: Surprised
# 20: Surprised
# 20: Surprised

# %%
#do pca with dimensions as columns, display dimensions with highest loadings on top eigenvectors
print "****** PCA on dimensions******"
pcaondimsresults=ndaw.pcaanalysis(itemavgs, 'dimensions', dimlabels, item2emomapping, savepath, 'item-wise correlations (of tranformed item vectors in dimension PC space)', orderedlabels, suffix)
# Out:
# ****** PCA on dimensions******
# eigenvector #1--- high-loaders: fairness, goal_consistency, pleasantness; loadings: 0.301, 0.311, 0.372
# eigenvector #2--- high-loaders: self_cause, bodily_disease, self_involvement; loadings: 0.187, 0.201, 0.255
# eigenvector #3--- high-loaders: coping, danger, agent_situation; loadings: 0.162, 0.226, 0.231
# eigenvector #4--- high-loaders: control, expectedness, repetition; loadings: 0.198, 0.2, 0.319
# eigenvector #5--- high-loaders: pressure, agent_intention, future; loadings: 0.199, 0.242, 0.271
# eigenvector #6--- high-loaders: agent_intention, occurred, agent_cause; loadings: 0.236, 0.306, 0.451
# eigenvector #7--- high-loaders: self_cause, freedom, close_others; loadings: 0.246, 0.393, 0.501
# eigenvector #8--- high-loaders: agent_cause, bodily_disease, agent_intention; loadings: 0.261, 0.271, 0.413
# eigenvector #9--- high-loaders: suddenness, future, agent_cause; loadings: 0.209, 0.319, 0.423
# eigenvector #10--- high-loaders: knowledge_change, agent_intention, past; loadings: 0.206, 0.263, 0.418
# eigenvector #11--- high-loaders: safey, occurred, consequences; loadings: 0.188, 0.196, 0.255
# eigenvector #12--- high-loaders: pressure, people, altering; loadings: 0.263, 0.304, 0.45

# %%
#do pca with items as columns, display items with highest loadings on top eigenvectors
print "****** PCA on items******"
pcaonitemsresults=ndaw.pcaanalysis(itemavgs, 'items', orderedlabels, item2emomapping, savepath, 'item-wise correlations (of tranformed dimension vectors in item PC space)', orderedlabels, suffix)
# Out:
# ****** PCA on items******
# eigenvector #1--- high-loaders: q142, q148, q149; emos: Grateful, Grateful, Grateful; loadings: 0.301, 0.311, 0.372
# eigenvector #2--- high-loaders: q144, q158, q152; emos: Grateful, Hopeful, Hopeful; loadings: 0.187, 0.201, 0.255
# eigenvector #3--- high-loaders: q178, q153, q133; emos: Joyful, Hopeful, Excited; loadings: 0.162, 0.226, 0.231
# eigenvector #4--- high-loaders: q150, q147, q179; emos: Grateful, Grateful, Joyful; loadings: 0.198, 0.2, 0.319
# eigenvector #5--- high-loaders: q156, q141, q174; emos: Hopeful, Grateful, Joyful; loadings: 0.199, 0.242, 0.271
# eigenvector #6--- high-loaders: q141, q172, q143; emos: Grateful, Joyful, Grateful; loadings: 0.236, 0.306, 0.451
# eigenvector #7--- high-loaders: q144, q157, q145; emos: Grateful, Hopeful, Grateful; loadings: 0.246, 0.393, 0.501
# eigenvector #8--- high-loaders: q143, q158, q141; emos: Grateful, Hopeful, Grateful; loadings: 0.261, 0.271, 0.413
# eigenvector #9--- high-loaders: q176, q174, q143; emos: Joyful, Joyful, Grateful; loadings: 0.209, 0.319, 0.423
# eigenvector #10--- high-loaders: q136, q141, q173; emos: Excited, Grateful, Joyful; loadings: 0.206, 0.263, 0.418
# eigenvector #11--- high-loaders: q137, q172, q151; emos: Excited, Joyful, Hopeful; loadings: 0.188, 0.196, 0.255
# eigenvector #12--- high-loaders: q156, q155, q146; emos: Hopeful, Hopeful, Grateful; loadings: 0.263, 0.304, 0.45

# %%
#classify emo based on all dimensions, cross validate across split halves, display emo similarity space in each fold
classresults={}
print "****** evenodd classifications******"
cvfolds=range(2) # evenodd takes values 0 and 1
cvtype='evenodd'
classresults[cvtype]=ndaw.classifyitemsummaries(cvfolds, cvtype, keepers, orderedlabels, orderedemos, item2emomapping, savepath, matrixtitle='emo-wise correlations (across items)', savetitle='emosimilarities_xhalves', suffix=suffix)
# Out:
# ****** evenodd classifications******
# found 197
# found 188

# %%
#Classify emo based on dimensions...do things seperately for different subsets of the items.
#note: do randomized permutations rather than fixed folds based on hitnum...put the following inside a permutation loop and set hitnum=indices[i]
#display similarity matrices for different folds (comment out the plotting if doing permutation)
#indices=range(5)
#shuffle(indices)
print "****** stimnum classifications******"
cvfolds=range(1,numstimsperemo+1) #stimnums start at 1
cvtype='stimnum'
classresults[cvtype]=ndaw.classifyitemsummaries(cvfolds, cvtype, keepers, orderedlabels, orderedemos, item2emomapping, savepath, matrixtitle='emo-wise correlations (across items)', savetitle='emosimilarities_xhalves', suffix=suffix)
# Out:
# ****** stimnum classifications******
# found 20
# found 20
# found 20
# found 19
# found 20
# found 19
# found 20
# found 20
# found 19
# found 20

# %%
#plot various classification results
ndaw.plotclassresults(classresults)

# %% [raw]
# figure out how to show that you are capitalizing on a higher-d space
#     -show that eigenvectors explaining the most variance aren't just valence?
#     -show that you can classify even if excluding valence related dimensions?
#     -show that you take a hit if reducing to massively lower-d space?
#     -show that you can classify above chance when analyzing within positive and negative valence separately?

# %% [raw]
# compare nlp classification based on appraisals to..
#     -single level classification based on bag of words
#     -multilevel algorithm that estimates probabability of appraisals from words, and then emo label from appraisals

# %% [raw]
# individiual differences?
# asd?
# explain errors in terms of appraisal extraction? e.g. when emotions are ambiguous or there is less agreement is it because people differ in their appraisal judgments or in the appraisal/emotion mappings?
